# %%
import numpy as np

# %%
height =[23,34,46,78]

# %%
weight =[35,47,49,47]

# %%
height_arr = np.array(height)
weight_arr = np.array(weight)

# %%
height_arr
# Out:
# array([23, 34, 46, 78])

# %%
weight_arr
# Out:
# array([35, 47, 49, 47])

# %%
soln = height_arr/weight_arr
soln
# Out:
# array([0.65714286, 0.72340426, 0.93877551, 1.65957447])

# %%
new_value = soln**2
new_value
# Out:
# array([0.43183673, 0.52331372, 0.88129946, 2.75418742])

# %%
type(new_value)
# Out:
# numpy.ndarray

# %%
type(height)
# Out:
# list

# %%
new_var = [63,45,73,36]
new_var2 =[35,46,47,37]

# %%
con = new_var + new_var2
con
# Out:
# [63, 45, 73, 36, 35, 46, 47, 37]

# %%
o = np.array(new_var )

# %% [raw]
# p = np.array(new_var2)

# %%
o
# Out:
# array([63, 45, 73, 36])

# %%
p
# Out:
# array([35, 46, 47, 37])

# %%
new_valu = o + p
new_valu
# Out:
# array([ 98,  91, 120,  73])

# %%
new_value = o / p
new_value
# Out:
# array([1.8       , 0.97826087, 1.55319149, 0.97297297])

# %%
new_value = o * p
new_value
# Out:
# array([2205, 2070, 3431, 1332])

# %%
 np.arange(0,100,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48,
#        51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99])

# %%
np.mean(new_valu)
# Out:
# 95.5

# %%
np.std(new_valu)
# Out:
# 16.830032679706836

# %%
np.median(new_valu)
# Out:
# 94.5

# %%
p>40
# Out:
# array([False,  True,  True, False])

# %%
o < 40
# Out:
# array([False, False, False,  True])

# %%
np.sin(60)
# Out:
# -0.3048106211022167

# %% [markdown]
# np.tan(45)

# %%
np.tan(45)
# Out:
# 1.6197751905438615

# %% [markdown]
# # PANDAS

# %%
import pandas as pd
from pandas import Series,DataFrame

# %%
age=Series([15,17,28,60],index=['big','bigger','biggest','old'])
age
# Out:
# big        15
# bigger     17
# biggest    28
# old        60
# dtype: int64

# %%
name = ['mark','bolu','mark','frank']
age = [20,36,38,34]
sex = ['male','female','male','male']
sch = ['lautech','lautech','unilag','lasu']

# %%
details = {'name' :name, 'age': age,'sex': sex}
new_details =DataFrame(details,index=['a','b','c','d'])
new_details[['name','sex','age']]
# Out:
#     name     sex  age
# a   mark    male   20
# b   bolu  female   36
# c   mark    male   38
# d  frank    male   34

# %%
details['institution'] = sch
new_details = DataFrame(details)
new_details
# Out:
#     name  age     sex institution
# 0   mark   20    male     lautech
# 1   bolu   36  female     lautech
# 2   mark   38    male      unilag
# 3  frank   34    male        lasu

# %%
import os

# %%
os.getcwd()#cwd (current working directly)
# Out:
# 'C:\\Users\\FAKUNLE'

# %%
new_work = pd.read_csv('train.csv')
new_work.head(10)
# Out:
#    S/N Gender  Age Location famsize Pstatus  Medu  Fedu  traveltime  \
# 0    1      F   13        U     GT3       A     4     4           2
# 1    2      F   12        U     GT3       T     1     1           1
# 2    3      F   10        U     LE3       T     1     1           1
# 3    4      F   10        U     GT3       T     4     2           1
# 4    5      F   11        U     GT3       T     3     3           1
# 5    6      M   11        U     LE3       T     4     3           1
# 6    7      M   11        U     LE3       T     2     2           1
# 7    8      F   12        U     GT3       A     4     4           2
# 8    9      M   10        U     LE3       A     3     2           1
# 9   10      M   10        U     GT3       T     3     4           1
#
#    studytime  ...    paid activities nursery higher internet famrel freetime  \
# 0          2  ...      no         no     yes    yes       no      4        3
# ...

# %%
#non_null means no value  is missing

# %%
new_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 23 columns):
# S/N           325 non-null int64
# Gender        325 non-null object
# Age           325 non-null int64
# Location      325 non-null object
# famsize       325 non-null object
# Pstatus       325 non-null object
# Medu          325 non-null int64
# Fedu          325 non-null int64
# traveltime    325 non-null int64
# studytime     325 non-null int64
# failures      325 non-null int64
# schoolsup     325 non-null object
# famsup        325 non-null object
# paid          325 non-null object
# activities    325 non-null object
# nursery       325 non-null object
# higher        325 non-null object
# internet      325 non-null object
# famrel        325 non-null int64
# freetime      325 non-null int64
# health        325 non-null int64
# absences      325 non-null int64
# Score         325 non-null int64
# dtypes: int64(12), object(11)
# memory usage: 58.5+ KB

# %%
new_work.describe()
# Out:
#               S/N         Age        Medu        Fedu  traveltime   studytime  \
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean   163.000000   11.320000    2.710769    2.476923    1.449231    1.956923
# std     93.963645    1.123157    1.086977    1.093015    0.725234    0.819133
# min      1.000000   10.000000    0.000000    0.000000    1.000000    1.000000
# 25%     82.000000   10.000000    2.000000    2.000000    1.000000    1.000000
# 50%    163.000000   11.000000    3.000000    2.000000    1.000000    2.000000
# 75%    244.000000   12.000000    4.000000    3.000000    2.000000    2.000000
# max    325.000000   17.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime      health    absences       Score
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean     0.184615    3.926154    3.178462    3.590769    4.341538   35.713846
# ...

# %%
new_work.isnull()
# Out:
#        S/N  Gender    Age  Location  famsize  Pstatus   Medu   Fedu  \
# 0    False   False  False     False    False    False  False  False
# 1    False   False  False     False    False    False  False  False
# 2    False   False  False     False    False    False  False  False
# 3    False   False  False     False    False    False  False  False
# 4    False   False  False     False    False    False  False  False
# 5    False   False  False     False    False    False  False  False
# 6    False   False  False     False    False    False  False  False
# 7    False   False  False     False    False    False  False  False
# 8    False   False  False     False    False    False  False  False
# 9    False   False  False     False    False    False  False  False
# 10   False   False  False     False    False    False  False  False
# 11   False   False  False     False    False    False  False  False
# 12   False   False  False     False    False    False  False  False
# ...

# %%
print(new_work.isnull().sum())
# Out:
# S/N           0
# Gender        0
# Age           0
# Location      0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# famrel        0
# freetime      0
# health        0
# absences      0
# Score         0
# dtype: int64

# %%
new_work.drop('Pstatus', axis = 1)
# Out:
#      S/N Gender  Age Location famsize  Medu  Fedu  traveltime  studytime  \
# 0      1      F   13        U     GT3     4     4           2          2
# 1      2      F   12        U     GT3     1     1           1          2
# 2      3      F   10        U     LE3     1     1           1          2
# 3      4      F   10        U     GT3     4     2           1          3
# 4      5      F   11        U     GT3     3     3           1          2
# 5      6      M   11        U     LE3     4     3           1          2
# 6      7      M   11        U     LE3     2     2           1          2
# 7      8      F   12        U     GT3     4     4           2          2
# 8      9      M   10        U     LE3     3     2           1          2
# 9     10      M   10        U     GT3     3     4           1          2
# 10    11      F   10        U     GT3     4     4           1          2
# 11    12      F   10        U     GT3     2     1           3          3
# ...

# %%
new_work.loc[307, 'Age']
# Out:
# 12

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline       
#with this no need for command.show()

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
#it allows you to brin
# Out:
#    S/N Gender  Age Location famsize Pstatus  Medu  Fedu  traveltime  \
# 0    1      F   13        U     GT3       A     4     4           2
# 1    2      F   12        U     GT3       T     1     1           1
# 2    3      F   10        U     LE3       T     1     1           1
# 3    4      F   10        U     GT3       T     4     2           1
# 4    5      F   11        U     GT3       T     3     3           1
#
#    studytime  ...    paid activities nursery higher internet famrel freetime  \
# 0          2  ...      no         no     yes    yes       no      4        3
# 1          2  ...      no         no      no    yes      yes      5        3
# 2          2  ...      no         no     yes    yes      yes      4        3
# 3          3  ...      no        yes     yes    yes      yes      3        2
# 4          2  ...      no         no     yes    yes       no      4        3
#
#   health  absences  Score
# 0      3         4     22
# 1      3         2     31
# ...

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
print(x)
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x,y,'y')
plt.show()
plt.plot(y,x,'v')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'b')
plt.subplot(1,2,2)
plt.plot(x,y,'r')

# %%
fig = plt.figure(figsize=(8,4), dpi=100)
