# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series,DataFrame

# %%
new_work = pd.read_csv('train2.csv')
new_work.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
# ...

# %%
new_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
# Product_Identifier                4990 non-null object
# Supermarket_Identifier            4990 non-null object
# Product_Supermarket_Identifier    4990 non-null object
# Product_Weight                    4188 non-null float64
# Product_Fat_Content               4990 non-null object
# Product_Shelf_Visibility          4990 non-null float64
# Product_Type                      4990 non-null object
# Product_Price                     4990 non-null float64
# Supermarket_Opening_Year          4990 non-null int64
# Supermarket _Size                 3540 non-null object
# Supermarket_Location_Type         4990 non-null object
# Supermarket_Type                  4990 non-null object
# Product_Supermarket_Sales         4990 non-null float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 506.9+ KB

# %%
new_work.isnull()
# Out:
#       Product_Identifier  Supermarket_Identifier  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# 5                  False                   False
# 6                  False                   False
# 7                  False                   False
# 8                  False                   False
# 9                  False                   False
# 10                 False                   False
# 11                 False                   False
# 12                 False                   False
# 13                 False                   False
# 14                 False                   False
# 15                 False                   False
# 16                 False                   False
# 17                 False                   False
# ...

# %%
new_work.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                     802
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1450
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
new_work.describe()
# Out:
#        Product_Weight  Product_Shelf_Visibility  Product_Price  \
# count     4188.000000               4990.000000    4990.000000
# mean        12.908838                  0.066916     391.803796
# std          4.703256                  0.053058     119.378259
# min          4.555000                  0.000000      78.730000
# 25%          8.767500                  0.027273     307.890000
# 50%         12.600000                  0.053564     393.860000
# 75%         17.100000                  0.095358     465.067500
# max         21.350000                  0.328391     667.220000
#
#        Supermarket_Opening_Year  Product_Supermarket_Sales
# count               4990.000000                4990.000000
# mean                2004.783567                6103.520164
# std                    8.283151                4447.333835
# min                 1992.000000                  83.230000
# 25%                 1994.000000                2757.660000
# ...

# %%
new_work['Product_Fat_Content'].value_counts()
# Out:
# 0    3039
# 1    1773
# 2     178
# Name: Product_Fat_Content, dtype: int64

# %%
new_work['Supermarket _Size'].value_counts()
# Out:
# Medium    1582
# Small     1364
# High       594
# Name: Supermarket _Size, dtype: int64

# %%
new_work['Product_Type'].value_counts()
# Out:
# Snack Foods              758
# Fruits and Vegetables    747
# Household                567
# Frozen Foods             457
# Canned                   376
# Dairy                    350
# Baking Goods             344
# Health and Hygiene       307
# Meat                     264
# Soft Drinks              261
# Breads                   137
# Hard Drinks              134
# Others                   100
# Starchy Foods             81
# Breakfast                 66
# Seafood                   41
# Name: Product_Type, dtype: int64

# %%
new_work['Supermarket_Location_Type'].value_counts()
# Out:
# Cluster 3    1940
# Cluster 2    1581
# Cluster 1    1469
# Name: Supermarket_Location_Type, dtype: int64

# %%
new_work['Supermarket_Type'].value_counts()
# Out:
# Supermarket Type1    3304
# Grocery Store         724
# Supermarket Type2     500
# Supermarket Type3     462
# Name: Supermarket_Type, dtype: int64

# %%
mean = new_work['Product_Weight'].mean()
new_work['Product_Weight']= new_work['Product_Weight'].fillna(mean)

# %%
new_work.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                       0
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1450
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
new_work['Product_Type'] = encoder.fit_transform(new_work['Product_Type'])
new_work['Product_Type'].head()
# Out:
# 0    14
# 1    14
# 2    14
# 3    14
# 4    14
# Name: Product_Type, dtype: int64

# %%
new_work.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility  Product_Type  \
# 0            11.6             Low Fat                  0.068535            14
# 1            11.6             Low Fat                  0.040912            14
# 2            11.6             Low Fat                  0.041178            14
# 3            11.6             Low Fat                  0.041113            14
# 4            11.6       Ultra Low fat                  0.000000            14
#
# ...

# %%
new_work['Product_Fat_Content'] = encoder.fit_transform(new_work['Product_Fat_Content'])
new_work['Product_Fat_Content'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    2
# Name: Product_Fat_Content, dtype: int64

# %%
new_work['Supermarket_Type'] =  encoder.fit_transform(new_work['Supermarket_Type'])
new_work['Supermarket_Type'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    2
# 4    1
# Name: Supermarket_Type, dtype: int64

# %%
new_work['Supermarket_Location_Type'] =  encoder.fit_transform(new_work['Supermarket_Location_Type'])
new_work['Supermarket_Location_Type'].head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    2
# 4    1
# Name: Supermarket_Location_Type, dtype: int64

# %%
new_work['Product_Supermarket_Sales'] =  encoder.fit_transform(new_work['Product_Supermarket_Sales'])
new_work['Product_Supermarket_Sales'].head()
# Out:
# 0     216
# 1    1442
# 2    1442
# 3     545
# 4     619
# Name: Product_Supermarket_Sales, dtype: int64

# %%
new_work['Product_Price'] =  encoder.fit_transform(new_work['Product_Price'])
new_work['Product_Price' ].head()
# Out:
# 0    1321
# 1    1299
# 2    1237
# 3    1291
# 4    1288
# Name: Product_Price, dtype: int64

# %%
new_work['Supermarket _Size'] =new_work['Supermarket _Size'].fillna('low_viz')
new_work['Supermarket _Size' ].value_counts()
# Out:
# Medium     1582
# low_viz    1450
# Small      1364
# High        594
# Name: Supermarket _Size, dtype: int64

# %%
new_work.isnull().sum()
# Out:
# Product_Identifier                0
# Supermarket_Identifier            0
# Product_Supermarket_Identifier    0
# Product_Weight                    0
# Product_Fat_Content               0
# Product_Shelf_Visibility          0
# Product_Type                      0
# Product_Price                     0
# Supermarket_Opening_Year          0
# Supermarket _Size                 0
# Supermarket_Location_Type         0
# Supermarket_Type                  0
# Product_Supermarket_Sales         0
# dtype: int64

# %%
df = new_work[['Product_Weight','Product_Fat_Content','Product_Shelf_Visibility','Product_Type','Product_Price','Supermarket_Opening_Year','Supermarket _Size','Supermarket_Location_Type' ,'Supermarket_Type','Product_Supermarket_Sales' 
]]

# %%
import seaborn as sns
corr_matrix = df.corr()
f, ax = plt.subplots(figsize=(18,10))
sns.heatmap(corr_matrix,lw=2.0,ax=ax, annot=True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')

# %%
df.corr()
# Out:
#                            Product_Weight  Product_Fat_Content  \
# Product_Weight                   1.000000            -0.020393
# Product_Fat_Content             -0.020393             1.000000
# Product_Shelf_Visibility        -0.022309             0.057196
# Product_Type                     0.030124            -0.118499
# Product_Price                    0.028400            -0.001876
# Supermarket_Opening_Year         0.006867             0.004123
# Supermarket_Location_Type       -0.004236             0.011743
# Supermarket_Type                 0.003061             0.002929
# Product_Supermarket_Sales        0.013905             0.012277
#
#                            Product_Shelf_Visibility  Product_Type  \
# Product_Weight                            -0.022309      0.030124
# Product_Fat_Content                        0.057196     -0.118499
# Product_Shelf_Visibility                   1.000000     -0.037179
# Product_Type                              -0.037179      1.000000
# ...

# %%
import seaborn as sns
corr_matrix = df.corr()
f, ax = plt.subplots(figsize=(18,10))
sns.heatmap(corr_matrix,lw=2.0,ax=ax, annot=True)
ax.set_title('Correlation Matrix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ba4d3eb45720> in <module>()
#       1 import seaborn as sns
# ----> 2 corr_matrix = df.corr()
#       3 f, ax = plt.subplots(figsize=(18,10))
#       4 sns.heatmap(corr_matrix,lw=2.0,ax=ax, annot=True)
#       5 ax.set_title('Correlation Matrix')
#
# NameError: name 'df' is not defined
