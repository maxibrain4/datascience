# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('test.csv')
dataset.head()
# Out:
#    S/N  Age Location famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0  327   12        U     LE3       A     3     2           1          1
# 1  328   13        R     LE3       T     1     1           2          4
# 2  329   13        U     GT3       T     1     1           2          2
# 3  330   12        U     GT3       T     2     2           1          2
# 4  331   13        U     GT3       T     2     1           2          2
#
#    failures    ...    famsup paid activities nursery higher internet famrel  \
# 0         0    ...        no   no         no     yes    yes      yes      4
# 1         0    ...       yes   no        yes     yes    yes       no      5
# 2         0    ...        no   no        yes     yes    yes      yes      5
# 3         0    ...       yes   no         no      no    yes      yes      5
# 4         0    ...        no   no        yes     yes    yes      yes      4
#
#    freetime  health  absences
# 0         4       3        18
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 21 columns):
# S/N           323 non-null int64
# Age           323 non-null int64
# Location      323 non-null object
# famsize       323 non-null object
# Pstatus       323 non-null object
# Medu          323 non-null int64
# Fedu          323 non-null int64
# traveltime    323 non-null int64
# studytime     323 non-null int64
# failures      323 non-null int64
# schoolsup     323 non-null object
# famsup        323 non-null object
# paid          323 non-null object
# activities    323 non-null object
# nursery       323 non-null object
# higher        323 non-null object
# internet      323 non-null object
# famrel        323 non-null int64
# freetime      323 non-null int64
# health        323 non-null int64
# absences      323 non-null int64
# dtypes: int64(11), object(10)
# memory usage: 53.1+ KB

# %%
dataset.describe()
# Out:
#               S/N         Age        Medu        Fedu  traveltime   studytime  \
# count  323.000000  323.000000  323.000000  323.000000  323.000000  323.000000
# mean   488.000000   12.170279    2.312693    2.139319    1.687307    1.907121
# std     93.386294    1.163143    1.146718    1.081652    0.754732    0.840019
# min    327.000000   10.000000    0.000000    0.000000    1.000000    1.000000
# 25%    407.500000   11.000000    1.000000    1.000000    1.000000    1.000000
# 50%    488.000000   12.000000    2.000000    2.000000    2.000000    2.000000
# 75%    568.500000   13.000000    3.000000    3.000000    2.000000    2.000000
# max    649.000000   16.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime      health    absences
# count  323.000000  323.000000  323.000000  323.000000  323.000000
# mean     0.260062    3.934985    3.176471    3.476780    2.916409
# std      0.605756    0.999433    1.110287    1.453819    3.750256
# ...

# %%
dataset.isnull()
# Out:
#        S/N    Age  Location  famsize  Pstatus   Medu   Fedu  traveltime  \
# 0    False  False     False    False    False  False  False       False
# 1    False  False     False    False    False  False  False       False
# 2    False  False     False    False    False  False  False       False
# 3    False  False     False    False    False  False  False       False
# 4    False  False     False    False    False  False  False       False
# 5    False  False     False    False    False  False  False       False
# 6    False  False     False    False    False  False  False       False
# 7    False  False     False    False    False  False  False       False
# 8    False  False     False    False    False  False  False       False
# 9    False  False     False    False    False  False  False       False
# 10   False  False     False    False    False  False  False       False
# 11   False  False     False    False    False  False  False       False
# ...

# %%
dataset.isnull().sum()
# Out:
# S/N           0
# Age           0
# Location      0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# famrel        0
# freetime      0
# health        0
# absences      0
# dtype: int64

# %%
dataset['Location'].value_counts()
# Out:
# U    186
# R    137
# Name: Location, dtype: int64

# %%
dataset['famsize'].value_counts()
# Out:
# GT3    223
# LE3    100
# Name: famsize, dtype: int64

# %%
dataset['Pstatus'].value_counts()
# Out:
# T    284
# A     39
# Name: Pstatus, dtype: int64

# %%
dataset['famsup'].value_counts()
# Out:
# yes    192
# no     131
# Name: famsup, dtype: int64

# %%
dataset['paid'].value_counts()
# Out:
# no     305
# yes     18
# Name: paid, dtype: int64

# %%
dataset['activities'].value_counts()
# Out:
# no     180
# yes    143
# Name: activities, dtype: int64

# %%
dataset['nursery'].value_counts()
# Out:
# yes    265
# no      58
# Name: nursery, dtype: int64

# %%
dataset['higher'].value_counts()
# Out:
# yes    282
# no      41
# Name: higher, dtype: int64

# %%
dataset['internet'].value_counts()
# Out:
# yes    229
# no      94
# Name: internet, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset['Location'] = encoder.fit_transform(dataset['Location'])
dataset['Location'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Location, dtype: int64

# %%
dataset['famsize'] = encoder.fit_transform(dataset['famsize'])
dataset['famsize'].head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: famsize, dtype: int64

# %%
dataset['Pstatus'] = encoder.fit_transform(dataset['Pstatus'])
dataset['Pstatus'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Pstatus, dtype: int64

# %%
dataset['famsup'] = encoder.fit_transform(dataset['famsup'])
dataset['famsup'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: famsup, dtype: int64

# %%
dataset['paid'] = encoder.fit_transform(dataset['paid'])
dataset['paid'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: paid, dtype: int64

# %%
dataset['activities'] = encoder.fit_transform(dataset['activities'])
dataset['activities'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: activities, dtype: int64

# %%
dataset['nursery'] = encoder.fit_transform(dataset['nursery'])
dataset['nursery'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: nursery, dtype: int64

# %%
dataset['higher'] = encoder.fit_transform(dataset['higher'])
dataset['higher'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: higher, dtype: int64

# %%
dataset['internet'] = encoder.fit_transform(dataset['internet'])
dataset['internet'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: internet, dtype: int64

# %%
df = dataset[['S/N','Age','Location','famsize','Pstatus','Medu','Fedu','traveltime','studytime','failures','schoolsup','famsup','paid','activities','nursery','higher','internet','famrel','freetime','health','absences']]

# %%
import seaborn as sns
corr_matrix = df.corr()
f, ax = plt.subplots(figsize=(18,10))
sns.heatmap(corr_matrix,lw=2.0,ax=ax, annot=True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')

# %%
df.corr()
# Out:
#                  S/N       Age  Location   famsize   Pstatus      Medu  \
# S/N         1.000000  0.027076 -0.192351  0.022048  0.002548 -0.132677
# Age         0.027076  1.000000  0.190566 -0.046290 -0.043847  0.036793
# Location   -0.192351  0.190566  1.000000  0.032721 -0.125774  0.174205
# famsize     0.022048 -0.046290  0.032721  1.000000 -0.286204  0.027668
# Pstatus     0.002548 -0.043847 -0.125774 -0.286204  1.000000 -0.006680
# Medu       -0.132677  0.036793  0.174205  0.027668 -0.006680  1.000000
# Fedu       -0.133464  0.045265  0.139716  0.006623  0.012612  0.658321
# traveltime  0.238994 -0.077128 -0.347812 -0.059812  0.098415 -0.277802
# studytime  -0.200517  0.070271  0.129032  0.066172 -0.041037  0.101172
# failures    0.151740  0.329241 -0.065994 -0.144004 -0.076314 -0.126374
# famsup     -0.168114 -0.161219  0.005569 -0.019676  0.022887  0.104432
# paid        0.053845  0.045730 -0.009977 -0.045912  0.007181  0.110469
# ...
